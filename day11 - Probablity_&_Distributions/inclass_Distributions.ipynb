# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = sns.load_dataset('tips')
df.head()

# %%
# how many unique values do you see in all the columns, and what can you infer
# what is the average bill amout
# what is the average tip amount
# just find some new insight

# %%
df.head(10)

# numerical - where you have numbers, integers, floats 

# categorical - in which you have classes/group of things
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2

# %%
# categorical data

df['day'].unique()
df['time'].unique()
df['size'].unique()

df['size'].value_counts()
# Out:
# size
# 2    156
# 3     38
# 4     37
# 5      5
# 1      4
# 6      4
# Name: count, dtype: int64

# %%
df["total_bill"].__len__()
df['total_bill'].value_counts()
# Out:
# total_bill
# 13.42    3
# 13.81    2
# 15.98    2
# 17.92    2
# 10.07    2
#         ..
# 24.71    1
# 21.16    1
# 28.97    1
# 22.49    1
# 18.78    1
# Name: count, Length: 229, dtype: int64

# %%
df['tip'].value_counts()
# Out:
# tip
# 2.00    33
# 3.00    23
# 4.00    12
# 5.00    10
# 2.50    10
#         ..
# 4.34     1
# 1.56     1
# 5.20     1
# 2.60     1
# 1.75     1
# Name: count, Length: 123, dtype: int64

# %%
df["tip"].unique() # wont give result u can use
df["tip"].value_counts()
# Out:
# tip
# 2.00    33
# 3.00    23
# 4.00    12
# 5.00    10
# 2.50    10
#         ..
# 4.34     1
# 1.56     1
# 5.20     1
# 2.60     1
# 1.75     1
# Name: count, Length: 123, dtype: int64

# %%
# check, how many rich or generous people come to our restaurant 

# what is the size or rich people or high class people visiting a place to buy

# max of the total bill

df['total_bill'].max()

# values for tips
df['tip'].max()
# Out:
# np.float64(10.0)

# %%
df.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3

# %%
y = df['size'].value_counts()
y[4]
# Out:
# np.int64(37)

# %%
x = df['size']
y = df['size'].value_counts()

# %%
# create a bar graph for size column
x = df['size'].unique()
y = df['size'].value_counts()

plt.bar(x,y)
# Out:
# <BarContainer object of 6 artists>

# %%
series_time = df['time'].value_counts()
series_time
# Out:
# time
# Dinner    176
# Lunch      68
# Name: count, dtype: int64

# %%
x = series_time.index
x
# Out:
# CategoricalIndex(['Dinner', 'Lunch'], categories=['Lunch', 'Dinner'], ordered=False, dtype='category', name='time')

# %%
sns.barplot(data=df, x='size', y=y)
# Out:
# <Axes: xlabel='size', ylabel='count'>

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
x = df['tip'].unique()
y = df['tip'].value_counts()

sns.barplot(data=df, x='tip' ,y=y )
# Out:
# <Axes: xlabel='tip', ylabel='count'>

# %%
# histogram

sns.histplot(data = df, x = 'sex')
# Out:
# <Axes: xlabel='sex', ylabel='Count'>

# %% [markdown]
# # Prediction - healthcare, cancer prediction - xrays
# # data -
#
# Distribution
#
# how the frequency of something is distributed.
#
# That if you take a sample size of 100 people:
#
# I want to know how tall the people of Philio are, ages between 18 to 45
#
# 7 feet
#
# 5 feet
#
# 3 feet
#
# Selecting a sample size: 5K -> 100
#
# measuring
#
# rows of data: 100 rows of data
#
# name age height gender ethnicity
#
# AI ETHICS
# data privacy - if the data is safe with the researchers - anonimity
# data transparency - how are you using the data

# %%
#my try

sum_bill = df['total_bill'].mean()
print(sum_bill)
# Out:
# 19.78594262295082

# %%
df['total_bill'].max()
# Out:
# np.float64(50.81)

# %%
df['tip'].max()

df_tips = df['tip']
df_tips
# Out:
# 0      1.01
# 1      1.66
# 2      3.50
# 3      3.31
# 4      3.61
#        ...
# 239    5.92
# 240    2.00
# 241    2.00
# 242    1.75
# 243    3.00
# Name: tip, Length: 244, dtype: float64

# %%
sum_tip = df['tip'].mean()
print(sum_tip)
# Out:
# 2.99827868852459

# %%
df['time'].unique()
# Out:
# ['Dinner', 'Lunch']
# Categories (2, object): ['Lunch', 'Dinner']

# %%
df['day'].unique()
# Out:
# ['Sun', 'Sat', 'Thur', 'Fri']
# Categories (4, object): ['Thur', 'Fri', 'Sat', 'Sun']

# %%
df['size'].unique()
# Out:
# array([2, 3, 4, 1, 6, 5])

# %%
df['size'].unique()
# Out:
# array([2, 3, 4, 1, 6, 5])

# %%
df_size = df['size']
df_size
# Out:
# 0      2
# 1      3
# 2      3
# 3      2
# 4      4
#       ..
# 239    3
# 240    2
# 241    2
# 242    2
# 243    2
# Name: size, Length: 244, dtype: int64

# %%
#sns.barplot(x='size', y='total_bill', data=df)

sns.barplot(x=df_size.unique(), y=df_size.value_counts())
# Out:
# <Axes: ylabel='count'>

# %%
sns.histplot(df, x='size')
# Out:
# <Axes: xlabel='size', ylabel='Count'>

# %%
sns.histplot(df, x='tip')
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
df.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3

# %%
df['size'].value_counts()
# Out:
# size
# 2    156
# 3     38
# 4     37
# 5      5
# 1      4
# 6      4
# Name: count, dtype: int64

# %%
x = df['size'].unique()
y = df['size'].value_counts()
plt.bar(x,y)

#plt.bar('df['size'])
# Out:
# <BarContainer object of 6 artists>

# %%
df['tip'].value_counts()
# Out:
# tip
# 2.00    33
# 3.00    23
# 4.00    12
# 5.00    10
# 2.50    10
#         ..
# 4.34     1
# 1.56     1
# 5.20     1
# 2.60     1
# 1.75     1
# Name: count, Length: 123, dtype: int64

# %%
sns.histplot(df,x='total_bill')
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
data = {
    'name': ['idrees','hazirah','atirah','mel','nazri','ibrahim','amin'],
    'age': [29,24,31,27,20,18,27],
    'height':[185, 152, 163, 162,164,168,168],
    'gender':['m','f','f','f','m','m','m'],
    'ethnicity':['kashmiri','malay','malay','malay','malay','malay','malay']
}

import pandas as pd
df = pd.DataFrame(data)
df.head(7)
# Out:
#       name  age  height gender ethnicity
# 0   idrees   29     185      m  kashmiri
# 1  hazirah   24     152      f     malay
# 2   atirah   31     163      f     malay
# 3      mel   27     162      f     malay
# 4    nazri   20     164      m     malay
# 5  ibrahim   18     168      m     malay
# 6     amin   27     168      m     malay

# %%
sns.histplot(data=df, x='height')
# Out:
# <Axes: xlabel='height', ylabel='Count'>

# %%
df.head(2)
# Out:
#       name  age  height gender ethnicity
# 0   idrees   29     185      m  kashmiri
# 1  hazirah   24     152      f     malay

# %%
malay = df[df["ethnicity"] == ('malay')]
print(malay)

female = df[df["gender"] == ('f')]
print(female)

malay_over_21 = df[df["age"] > 21]
print(malay_over_21)
# Out:
#       name  age  height gender ethnicity
# 1  hazirah   24     152      f     malay
# 2   atirah   31     163      f     malay
# 3      mel   27     162      f     malay
# 4    nazri   20     164      m     malay
# 5  ibrahim   18     168      m     malay
# 6     amin   27     168      m     malay
#       name  age  height gender ethnicity
# 1  hazirah   24     152      f     malay
# 2   atirah   31     163      f     malay
# 3      mel   27     162      f     malay
#       name  age  height gender ethnicity
# 0   idrees   29     185      m  kashmiri
# 1  hazirah   24     152      f     malay
# 2   atirah   31     163      f     malay
# 3      mel   27     162      f     malay
# 6     amin   27     168      m     malay

# %%
sns.histplot(data = df, x = 'height'  )
# Out:
# <Axes: xlabel='height', ylabel='Count'>

# %%
df.head(2)
# Out:
#       name  age  height gender ethnicity
# 0   idrees   29     185      m  kashmiri
# 1  hazirah   24     152      f     malay

# %%
malay = df[    df['ethnicity'] == 'malay'    ]
print(malay)

female = df[    df['gender'] == 'f'    ]
print(female)

malayOver21 = df[    (df['ethnicity'] == 'malay')  &  (df['age'] > 21 )  ]
malayOver21


# & and
# | or
# Out:
#       name  age  height gender ethnicity
# 1  hazirah   24     152      f     malay
# 2   atirah   31     163      f     malay
# 3      mel   27     162      f     malay
# 4    nazri   20     164      m     malay
# 5  ibrahim   18     168      m     malay
# 6     amin   27     168      m     malay
#       name  age  height gender ethnicity
# 1  hazirah   24     152      f     malay
# 2   atirah   31     163      f     malay
# 3      mel   27     162      f     malay
#       name  age  height gender ethnicity
# 1  hazirah   24     152      f     malay
# 2   atirah   31     163      f     malay
# 3      mel   27     162      f     malay
# 6     amin   27     168      m     malay

# %%
sns.histplot(data = malay, x = 'height', kde=True )
# Out:
# <Axes: xlabel='height', ylabel='Count'>

# %%
df['ethnicity']
# Out:
# 0    kashmiri
# 1       malay
# 2       malay
# 3       malay
# 4       malay
# 5       malay
# 6       malay
# Name: ethnicity, dtype: object

# %%
malay = df[df["ethnicity"] == 'malay']
print(malay)

female = df[df["gender"] == 'f']
print(female)
# Out:
#       name  age  height gender ethnicity
# 1  hazirah   25     152      f     malay
# 2   atirah   25     163      f     malay
# 3      mel   25     162      f     malay
# 4    nazri   25     164      m     malay
# 5  ibrahim   25     168      m     malay
# 6     amin   25     168      m     malay
#       name  age  height gender ethnicity
# 1  hazirah   25     152      f     malay
# 2   atirah   25     163      f     malay
# 3      mel   25     162      f     malay

# %%
sns.histplot(df, x='height')
# Out:
# <Axes: xlabel='height', ylabel='Count'>

# %%
# EXERCISE 3

tips_df = sns.load_dataset("tips")
tips_df.head()

df = pd.DataFrame(tips_df)
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# create these data frames
# 1. only male
# 2. tips above 6 dollars
# 3. smokers dining(having dinner) on sunday 

maledf = tipsdf[ tipsdf['sex'] == 'Male'  ]

tips6 = tipsdf[ tipsdf['tip'] > 6  ]

smoker_dining_sunday = tipsdf[ (tipsdf['smoker'] == 'Yes' ) & ( tipsdf['time'] == 'Dinner')  & ( tipsdf['day'] == 'Sun' )  ]
smoker_dining_sunday

# %%
male_list = df[df["sex"] == 'Male']
print(male_list)

# %%
tip6 = df[df["tip"] > 6.0]
print(tip6)

# %%
# Conditional selection, or filtering rows based on conditions in pandas DataFrames

smoker_dining_sunday = df[(df["smoker"] == ('Yes')) & (df["day"] == ('Sun')) & (df["time"] == ('Dinner'))]
print(smoker_dining_sunday)
