# %%
import torch
x = torch.rand(5, 3)
print(x)
# Out:
# tensor([[0.9014, 0.1048, 0.6656],
#         [0.8314, 0.7262, 0.8527],
#         [0.9574, 0.4942, 0.7988],
#         [0.2113, 0.0448, 0.9008],
#         [0.2873, 0.4240, 0.8036]])

# %%
import torch as th

# %%
import torch
if torch.backends.mps.is_available():
    mps_device = torch.device("mps")
    x = torch.ones(1, device=mps_device)
    print (x)
else:
    print ("MPS device not found.")
# Out:
# tensor([1.], device='mps:0')

# %%
import torch
