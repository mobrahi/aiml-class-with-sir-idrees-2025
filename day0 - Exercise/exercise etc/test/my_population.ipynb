# %%
pip install pandas fastparquet
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
URL_DATA = 'https://storage.dosm.gov.my/population/population_malaysia.parquet'

df = pd.read_parquet(URL_DATA)
if 'date' in df.columns: df['date'] = pd.to_datetime(df['date'])

df.index
#df.head()
# Out:
# RangeIndex(start=0, stop=17415, step=1)

# %%
# If not already installed, do: pip install pandas fastparquet
import pandas as pd

URL_DATA = 'https://storage.dosm.gov.my/hies/hh_inequality.parquet'

df_inequality = pd.read_parquet(URL_DATA)
if 'date' in df_inequality.columns: df_inequality['date'] = pd.to_datetime(df_inequality['date'])

df_inequality.index

#print(df_inequality)
# Out:
# RangeIndex(start=0, stop=20, step=1)

# %%
URL_DATA = 'https://storage.dosm.gov.my/hies/hh_poverty.parquet'

df_poverty = pd.read_parquet(URL_DATA)
if 'date' in df.columns: df_poverty['date'] = pd.to_datetime(df_poverty['date'])

df_poverty.index

#print(df_poverty)
# Out:
# RangeIndex(start=0, stop=20, step=1)

# %%
URL_DATA = 'https://storage.dosm.gov.my/hies/hh_income.parquet'

df_hh_income = pd.read_parquet(URL_DATA)
if 'date' in df_hh_income.columns: df_hh_income['date'] = pd.to_datetime(df_hh_income['date'])

df_hh_income.index
# Out:
# RangeIndex(start=0, stop=21, step=1)

# %%
URL_DATA = 'https://storage.dosm.gov.my/gdp/gdp_gni_annual_nominal.parquet'

df_gdp = pd.read_parquet(URL_DATA)
if 'date' in df.columns: df_gdp['date'] = pd.to_datetime(df_gdp['date'])

df_gdp.index
#print(df_gdp)
# Out:
# RangeIndex(start=0, stop=155, step=1)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#drop 1948 - 1969 data

start_index = 0
end_index = 23

df_dropped_gdp = df_gdp.drop(range(start_index, end_index)).reset_index(drop=True)

df_gdp_new = df_dropped_gdp
df_gdp_new.index
# Out:
# RangeIndex(start=0, stop=132, step=1)

# %%
dfs3 = [df_inequality, df_poverty, df_hh_income]

# %%
df_concat = pd.concat(dfs3, axis=1)
df_concat
# Out:
#          date   gini       date  poverty_absolute  poverty_hardcore  \
# 0  1970-01-01  0.513 1970-01-01              49.3               NaN
# 1  1974-01-01  0.530 1976-01-01              37.7               NaN
# 2  1976-01-01  0.557 1979-01-01              37.4               NaN
# 3  1979-01-01  0.505 1984-01-01              20.7               6.9
# 4  1984-01-01  0.483 1987-01-01              19.4               5.1
# 5  1987-01-01  0.456 1989-01-01              16.5               3.9
# 6  1989-01-01  0.442 1992-01-01              12.4               2.9
# 7  1992-01-01  0.451 1995-01-01               8.7               2.0
# 8  1995-01-01  0.456 1997-01-01               6.1               1.4
# 9  1997-01-01  0.459 1999-01-01               7.5               1.4
# 10 1999-01-01  0.443 2002-01-01               5.1               1.0
# 11 2002-01-01  0.461 2004-01-01               5.7               1.2
# 12 2004-01-01  0.462 2007-01-01               3.6               0.7
# ...

# %%
df_concat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   date              20 non-null     datetime64[ns]
#  1   gini              20 non-null     float64
#  2   date              20 non-null     datetime64[ns]
#  3   poverty_absolute  20 non-null     float64
#  4   poverty_hardcore  17 non-null     float64
#  5   poverty_relative  13 non-null     float64
#  6   date              21 non-null     datetime64[ns]
#  7   income_mean       21 non-null     Int64
#  8   income_median     21 non-null     Int64
# dtypes: Int64(2), datetime64[ns](3), float64(4)
# memory usage: 1.6 KB

# %%
import datetime

df_concat2['date'] = df_concat2['date'].apply(lambda x: x.strftime('%Y-%m-%d'))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[265], line 3
#       1 import datetime
# ----> 3 df_concat2['date'] = df_concat2['date'].apply(lambda x: x.strftime('%Y-%m-%d'))
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/pandas/core/series.py:4943, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4808 def apply(
#    4809     self,
#    4810     func: AggFuncType,
#    (...)   4815     **kwargs,
#    4816 ) -> DataFrame | Series:
#    4817     """
#    4818     Invoke function on values of Series.
#    4819
#    (...)   4934     dtype: float64
#    4935     """
#    4936     return SeriesApply(
#    4937         self,
#    4938         func,
#    4939         convert_dtype=convert_dtype,
#    4940         by_row=by_row,
#    4941         args=args,
#    4942         kwargs=kwargs,
# ...

# %%
df_concat.describe()

# %%
df_concat.isnull().sum()

# %%
df_concat.isnull().values.any()
# Out:
# np.True_

# %%
df_concat.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_concat.fillna(df_concat['poverty_hardcore'].max().round(1), inplace=True)

df_concat['poverty_hardcore'].isnull().sum()
# Out:
# /var/folders/wz/wy0brm1j5yggg1dvgql9qfhw0000gn/T/ipykernel_32400/2871049383.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '6.9' has dtype incompatible with datetime64[ns], please explicitly cast to a compatible dtype first.
#   df_concat.fillna(df_concat['poverty_hardcore'].max().round(1), inplace=True)
# np.int64(0)

# %%
df_concat[('poverty_hardcore')]
#df_concat

# %%
df_concat['poverty_relative'] = df_concat['poverty_relative'].fillna(19.62).round(1)

df_concat['poverty_relative'].isnull().sum()
# Out:
# np.int64(0)

# %%
df_concat['poverty_relative']
df_concat.head()

# %%
df_concat.drop(df.index[20], inplace=True)

df_concat

# %%
df_concat.isnull().sum()

# %%
#drop multi dates column

df_concat2 = df_concat.iloc[:, [0, 1, 3, 4, 5, 7,8]]

# %%
df_concat2
# Out:
#                    date   gini  poverty_absolute  poverty_hardcore  \
# 0   1970-01-01 00:00:00  0.513              49.3               6.9
# 1   1974-01-01 00:00:00  0.530              37.7               6.9
# 2   1976-01-01 00:00:00  0.557              37.4               6.9
# 3   1979-01-01 00:00:00  0.505              20.7               6.9
# 4   1984-01-01 00:00:00  0.483              19.4               5.1
# 5   1987-01-01 00:00:00  0.456              16.5               3.9
# 6   1989-01-01 00:00:00  0.442              12.4               2.9
# 7   1992-01-01 00:00:00  0.451               8.7               2.0
# 8   1995-01-01 00:00:00  0.456               6.1               1.4
# 9   1997-01-01 00:00:00  0.459               7.5               1.4
# 10  1999-01-01 00:00:00  0.443               5.1               1.0
# 11  2002-01-01 00:00:00  0.461               5.7               1.2
# 12  2004-01-01 00:00:00  0.462               3.6               0.7
# ...

# %%
df_concat2.to_csv('poverty_gap.csv', index=False)

# %%
import plotly.express as px

# %%
sns.pairplot(df_concat2)

# %%
plt.scatter(x=df_concat2['income_mean'], y=df_concat2['date'])

# %%
scatter_pov_inc = px.scatter(
    df_concat2,
    x= 'poverty_absolute',
    y= 'income_mean',
    #size= 'size',
    #color= 'day',
    #hover_data= ['sex', 'smoker', 'time'],
    #facet_col= ['time', 'sex', 'day', 'size']
)

scatter_pov_inc()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[252], line 11
#       1 scatter_pov_inc = px.scatter(
#       2     df_concat2,
#       3     x= 'poverty_absolute',
#    (...)      8     #facet_col= ['time', 'sex', 'day', 'size']
#       9 )
# ---> 11 scatter_pov_inc()
#
# TypeError: 'Figure' object is not callable

# %%
barplot = px.bar(df_concat2, x='date', y='income_mean')

barplot.show()

# %%
sns.countplot(df_concat2, x='income_mean', hue= 'date')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/pandas/core/algorithms.py:1516, in safe_sort(values, codes, use_na_sentinel, assume_unique, verify)
#    1515 try:
# -> 1516     sorter = values.argsort()
#    1517     ordered = values.take(sorter)
#
# TypeError: '<' not supported between instances of 'numpy.float64' and 'Timestamp'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/numpy/_core/fromnumeric.py:57, in _wrapfunc(obj, method, *args, **kwds)
#      56 try:
# ---> 57     return bound(*args, **kwds)
#      58 except TypeError:
# ...

# %%
sns.histplot(df_concat)
# Out:
# <Axes: ylabel='Count'>

# %%
plt.scatter(x=df_concat['poverty_absolute'], y=df_concat['poverty_relative'])

# %%
plt.figure(figsize= (15,8))
sns.heatmap(df_concat.corr(numeric_only=True), annot=True, linewidths=1, fmt=5, cmap='YlGnBu')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[235], line 2
#       1 plt.figure(figsize= (15,8))
# ----> 2 sns.heatmap(df_concat.corr(numeric_only=True), annot=True, linewidths=1, fmt=5, cmap='YlGnBu')
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/seaborn/matrix.py:459, in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     457 if square:
#     458     ax.set_aspect("equal")
# --> 459 plotter.plot(ax, cbar_ax, kwargs)
#     460 return ax
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/seaborn/matrix.py:352, in _HeatMapper.plot(self, ax, cax, kws)
#     350 # Annotate the cells with the formatted values
#     351 if self.annot:
# ...
