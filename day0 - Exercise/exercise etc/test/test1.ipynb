# %%
class SelamatDatang: 
    name = 'Idris'

    def welcome(name):
        return f'Welcome {name}!'

# %%
class simple_class:
    pass

# %%
class dog:
    def __init__(self):
        self.name = name
        self.breed = breed
    
    def bark(self):
        print(f'{self.name} says "woof!')

my_dog = dog('buddy','golden retriever')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 9
#       6     def bark(self):
#       7         print(f'{self.name} says "woof!')
# ----> 9 my_dog = dog('buddy','golden retriever')
#
# TypeError: dog.__init__() takes 1 positional argument but 3 were given

# %%
class Dog:
    def __init__(self, name, breed):
        self.name = name
        self.breed = breed

    def bark(self):
    print(f"{self.name} says Woof!")

# Instantiation: creating an instance of the Dog class
my_dog = Dog("Buddy", "Golden Retriever")
# Out:
#   Cell In[4], line 7
#     print(f"{self.name} says Woof!")
#     ^
# IndentationError: expected an indented block after function definition on line 6
