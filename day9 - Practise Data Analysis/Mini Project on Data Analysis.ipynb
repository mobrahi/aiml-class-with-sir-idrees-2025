# %%
import pandas as pd

import seaborn as sns

import matplotlib.pyplot as plt

df_titanic = pd.read_csv('titanic.csv')
#titanic = sns.load_dataset('titanic') -from github

# %%
df_titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df_titanic.shape
# Out:
# (891, 15)

# %%
df_titanic['age'] = df_titanic['age'].astype('int64')
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# Cell In[124], line 1
# ----> 1 df_titanic['age'] = df_titanic['age'].astype('int64')
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/pandas/core/generic.py:6665, in NDFrame.astype(self, dtype, copy, errors)
#    6659     results = [
#    6660         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6661     ]
#    6663 else:
#    6664     # else, only a single dtype is given
# -> 6665     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6666     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6667     return res.__finalize__(self, method="astype")
#
# ...

# %%
df_titanic = df_titanic.dropna()
df_titanic

# %%
df_titanic = df.drop('sibsp', axis=1)

# %%
sns.pairplot(df,hue='survived')

# %%
sns.scatterplot(x='age', y='survived', data=df)
# Out:
# <Axes: xlabel='age', ylabel='survived'>

# %%
sns.histplot(x='fare', data=df)
# Out:
# <Axes: xlabel='fare', ylabel='Count'>

# %%
sns.barplot(x='sex', y='survived', data=df)
# Out:
# <Axes: xlabel='sex', ylabel='survived'>

# %%
sns.barplot(x='class', y='survived', data=df)
# Out:
# <Axes: xlabel='class', ylabel='survived'>

# %%
sns.barplot(x='age', y='survived', data=df)
# Out:
# <Axes: xlabel='age', ylabel='survived'>

# %% [markdown]
# Analyze the context: Understand the "4 Ws": who is involved, what is the problem, where does it occur, and why is it important to solve?
#
# who : building owner
# what : owner not paying or late payment
# where : collection
# why : funds for asset repairs and upkeep is maintained at a health level

# %% [markdown]
# who: general population
# what: flooding
# where: peninsular malaysia
# why: absenteeism, death, monetary loss

# %%
import numpy as np

# a = np.arange(0,10000)
# b = np.arange(0,10000)
# c = np.arange(0,10000)
# d = np.arange(0,10000)

a = np.random.randint(500000,10000000,(500000,)) # start, stop, size
b = np.random.randint(500000,10000000,(500000,))
c = np.random.randint(500000,10000000,(500000,))
d = np.random.randint(500000,10000000,(500000,))

# %%
import pandas as pd

population = {
    'KL' : a,
    'JB' : b,
    'SG' : c,
    'PJ' : d
}

df = pd.DataFrame(population)
df.tail()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500000 entries, 0 to 499999
# Data columns (total 4 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   KL      500000 non-null  int64
#  1   JB      500000 non-null  int64
#  2   SG      500000 non-null  int64
#  3   PJ      500000 non-null  int64
# dtypes: int64(4)
# memory usage: 15.3 MB

# %%
df.to_csv('test_population.csv')

# %%
import pandas as pd

import seaborn as sns

import matplotlib.pyplot as plt


df = pd.read_csv('FloodDataset.csv')
print(df.head(5))
print(df.info)
df.shape
# Out:
#    STATE  DISTRICT  YEAR     JAN     FEB     MAR     APR     MAY     JUN  \
# 0    108    108001  2000  158.83  162.37  210.68  192.51  214.73  157.55
# 1    108    108001  2001  159.10   41.71  174.50  220.56  177.65  105.61
# 2    108    108001  2002   61.25   50.34   88.15  207.13  115.01   96.08
# 3    108    108001  2003   82.88  118.04  193.40  100.36  101.07  166.81
# 4    108    108001  2004  119.30   71.16  120.80  138.74  120.27  146.03
#
#       JUL     AUG     SEP     OCT      0V     DEC  ANNUAL RAINFALL  FLOOD
# 0   98.80  165.63  289.14  388.77  313.59  213.60          2566.19       0
# 1  166.59  193.88  206.40  298.14  232.54  150.82          2127.50       1
# 2  115.78  111.12  285.96  206.94  261.33  264.61          1863.70       1
# 3  167.61  270.87  238.84  682.07  251.46  182.35          2555.77       1
# 4  145.35  172.92  222.61  360.21  187.22  168.79          1973.39       1
# ...

# %%
sns.barplot(x='YEAR', y='ANNUAL RAINFALL', data=df)
# Out:
# <Axes: xlabel='YEAR', ylabel='ANNUAL RAINFALL'>

# %%
sns.barplot(x='YEAR', y='FLOOD ', data=df)
# Out:
# <Axes: xlabel='YEAR', ylabel='FLOOD '>

# %%
df.shape
# Out:
# (825, 17)

# %%
imprt
df_iris.to_csv('iris.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df_iris.to_csv('iris.csv')
#
# NameError: name 'df_iris' is not defined

# %%
import pandas as pd

df = pd.read_csv('iris.csv')

df.head(2)
df.info()
df.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB
# (150, 5)

# %%
#how to target a row

df.loc(4) # 

df['species'][8] #[column][row]
df.loc[4]['species'] # target the row
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/pandas/core/generic.py in ?(cls, axis)
#     579             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     580         except KeyError:
# --> 581             raise ValueError(f"No axis named {axis} for object type {cls.__name__}")
#
# KeyError: 4
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /var/folders/wz/wy0brm1j5yggg1dvgql9qfhw0000gn/T/ipykernel_74319/2455563521.py in ?()
#       1 #how to target a row
#       2
# ----> 3 df.loc(4)
#       4
#       5 df['species'][8] #[column][row]
#       6 df.loc[4]['species'] # target the row
#
# ...

# %%
x = [22,33,44,55]
x[2]
# Out:
# 44

# %%
df['species'] # columns
# Out:
# 0         setosa
# 1         setosa
# 2         setosa
# 3         setosa
# 4         setosa
#          ...
# 145    virginica
# 146    virginica
# 147    virginica
# 148    virginica
# 149    virginica
# Name: species, Length: 150, dtype: object

# %%
df.loc[4]['species']
# Out:
# 'setosa'

# %%
df.loc[0:4]['sepal_length']
# Out:
# 0    5.1
# 1    4.9
# 2    4.7
# 3    4.6
# 4    5.0
# Name: sepal_length, dtype: float64

# %%
df.head(2)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa

# %%
iris = pd.read_csv('iris.csv', header = None)
iris.head(2)
# Out:
#               0            1             2            3        4
# 0  sepal_length  sepal_width  petal_length  petal_width  species
# 1           5.1          3.5           1.4          0.2   setosa

# %%
iris = pd.read_csv('iris.csv', header = None, skiprows= 1)
iris.head(2)
# Out:
#      0    1    2    3       4
# 0  5.1  3.5  1.4  0.2  setosa
# 1  4.9  3.0  1.4  0.2  setosa

# %%
column = ['p_len','p_wid','s_len','s_wid','species']

iris = pd.read_csv('iris.csv', header = None, skiprows= 1, names= column)
iris.head(2)
# Out:
#    p_len  p_wid  s_len  s_wid species
# 0    5.1    3.5    1.4    0.2  setosa
# 1    4.9    3.0    1.4    0.2  setosa

# %%
iris.shape
# Out:
# (150, 5)
