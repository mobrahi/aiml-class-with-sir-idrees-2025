# %%
def greeting(geek,age,institute=''):
    print("hello",geek,"!!!")
    print(f"your age is: {age} ")
    print(f"your college: {institute} ")

geek = 'trainee'    
greeting(geek,18,'MIT')
greeting('coder',21,'none')
# Out:
# hello trainee !!!
# your age is: 18
# your college: MIT
# hello coder !!!
# your age is: 21
# your college: none

# %%
def greet(name):
    print(f"Hello, World!",name,"!!!")
    

name = "Welcome"

greet(name)
# Out:
# Hello, World! Welcome !!!

# %%
my_dict = {"name":"mohd", "age":28}
print(my_dict)
print(my_dict['name'])
print(my_dict['age'])
# Out:
# {'name': 'mohd', 'age': 28}
# mohd
# 28

# %%
my_list = [1,2,3,4]

my_list[0] = 10
print(my_list)
print(my_list[0:3])

#Square brackets are used to access elements in sequences like lists, strings, and tuples. 
#For example, my_list[0] or my_string[1:4]
# Out:
# [10, 2, 3, 4]
# [10, 2, 3]
